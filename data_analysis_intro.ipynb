# %% [markdown]
# # Import Pandas

# %%
import pandas as pd

# %% [markdown]
# # Importing Data

# %%
names = ["id", "title", "year", "rating", "votes", "length", "genres"]
data = pd.read_csv("imdb_top_10000.txt", sep="\t", names = names, index_col = 0)

# %% [markdown]
# # Exploring our Data

# %%
data.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres
# id
# tt0111161                       Crime|Drama
# tt0110912                    Crime|Thriller
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller

# %%
data.tail()
# Out:
#                                    title  year  rating  votes     length  \
# id
# tt0807721                 Meduzot (2007)  2007     7.0   1357   78 mins.
# tt0339642          Daltry Calhoun (2005)  2005     5.2   1357  100 mins.
# tt0060880  The Quiller Memorandum (1966)  1966     6.5   1356  104 mins.
# tt0152836                    Taal (1999)  1999     6.5   1356  179 mins.
# tt0279977          The Navigators (2001)  2001     6.9   1356   96 mins.
#
#                                genres
# id
# tt0807721                       Drama
# tt0339642  Comedy|Drama|Music|Romance
# tt0060880      Drama|Mystery|Thriller
# tt0152836             Musical|Romance
# tt0279977                Comedy|Drama

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, tt0111161 to tt0279977
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   10000 non-null  object
#  1   year    10000 non-null  int64
#  2   rating  10000 non-null  float64
#  3   votes   10000 non-null  int64
#  4   length  10000 non-null  object
#  5   genres  9999 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 546.9+ KB

# %%
data.describe()
# Out:
#                year        rating          votes
# count  10000.000000  10000.000000   10000.000000
# mean    1993.472800      6.386070   16604.012800
# std       14.829924      1.189933   34563.459698
# min     1950.000000      1.500000    1356.000000
# 25%     1986.000000      5.700000    2333.750000
# 50%     1998.000000      6.600000    4980.500000
# 75%     2005.000000      7.200000   15277.750000
# max     2011.000000      9.200000  619479.000000

# %% [markdown]
# # Exporting Data

# %%
data.to_csv("test.csv", header=True, index=True, sep=",")

# %%
data.sort_values(by="rating")
# Out:
#                                            title  year  rating   votes  \
# id
# tt0270846    Superbabies: Baby Geniuses 2 (2004)  2004     1.5   13196
# tt0059464                 Monster a-Go Go (1965)  1965     1.5    3255
# tt0364986                    Ben & Arthur (2002)  2002     1.5    4675
# tt0421051               Daniel the Wizard (2004)  2004     1.5    8271
# tt1309000                      Dream Well (2009)  2009     1.5    2848
# ...                                          ...   ...     ...     ...
# tt0071562          The Godfather: Part II (1974)  1974     9.0  291169
# tt0060196  The Good, the Bad and the Ugly (1966)  1966     9.0  195238
# tt0110912                    Pulp Fiction (1994)  1994     9.0  490065
# tt0068646                   The Godfather (1972)  1972     9.2  474189
# tt0111161        The Shawshank Redemption (1994)  1994     9.2  619479
#
#               length                              genres
# id
# tt0270846   88 mins.                       Comedy|Family
# tt0059464   70 mins.                       Sci-Fi|Horror
# tt0364986   85 mins.                       Drama|Romance
# tt0421051   81 mins.  Comedy|Crime|Family|Fantasy|Horror
# tt1309000   00 mins.                Comedy|Romance|Sport
# ...              ...                                 ...
# tt0071562  200 mins.                         Crime|Drama
# tt0060196  161 mins.                             Western
# tt0110912  154 mins.                      Crime|Thriller
# tt0068646  175 mins.                         Crime|Drama
# tt0111161  142 mins.                         Crime|Drama
#
# [10000 rows x 6 columns]

# %%
data.sort_values(by="rating", ascending=False)
# Out:
#                                            title  year  rating   votes  \
# id
# tt0111161        The Shawshank Redemption (1994)  1994     9.2  619479
# tt0068646                   The Godfather (1972)  1972     9.2  474189
# tt0060196  The Good, the Bad and the Ugly (1966)  1966     9.0  195238
# tt0110912                    Pulp Fiction (1994)  1994     9.0  490065
# tt0252487                Outrageous Class (1975)  1975     9.0    9823
# ...                                          ...   ...     ...     ...
# tt0364986                    Ben & Arthur (2002)  2002     1.5    4675
# tt0060753       Night Train to Mundo Fine (1966)  1966     1.5    3542
# tt0421051               Daniel the Wizard (2004)  2004     1.5    8271
# tt0059464                 Monster a-Go Go (1965)  1965     1.5    3255
# tt0060666        Manos: The Hands of Fate (1966)  1966     1.5   20927
#
#               length                              genres
# id
# tt0111161  142 mins.                         Crime|Drama
# tt0068646  175 mins.                         Crime|Drama
# tt0060196  161 mins.                             Western
# tt0110912  154 mins.                      Crime|Thriller
# tt0252487   87 mins.                        Comedy|Drama
# ...              ...                                 ...
# tt0364986   85 mins.                       Drama|Romance
# tt0060753   89 mins.          Action|Adventure|Crime|War
# tt0421051   81 mins.  Comedy|Crime|Family|Fantasy|Horror
# tt0059464   70 mins.                       Sci-Fi|Horror
# tt0060666   74 mins.                              Horror
#
# [10000 rows x 6 columns]

# %% [markdown]
# # Craeting Data Frames From Scratch

# %%
sample_data = {
    "tv": [33, 23, 55],
    "radio": [101, 103, 95],
    "news": [24, 45, 96],
    "sales": [10, 11, 14]
}

# %%
data2 = pd.DataFrame(sample_data)

# %%
data2
# Out:
#    tv  radio  news  sales
# 0  33    101    24     10
# 1  23    103    45     11
# 2  55     95    96     14

# %%
data["title"]
# Out:
# id
# tt0111161    The Shawshank Redemption (1994)
# tt0110912                Pulp Fiction (1994)
# tt0137523                  Fight Club (1999)
# tt0133093                  The Matrix (1999)
# tt1375666                   Inception (2010)
#                           ...
# tt0807721                     Meduzot (2007)
# tt0339642              Daltry Calhoun (2005)
# tt0060880      The Quiller Memorandum (1966)
# tt0152836                        Taal (1999)
# tt0279977              The Navigators (2001)
# Name: title, Length: 10000, dtype: object

# %%
data[["title", "year"]]
# Out:
#                                      title  year
# id
# tt0111161  The Shawshank Redemption (1994)  1994
# tt0110912              Pulp Fiction (1994)  1994
# tt0137523                Fight Club (1999)  1999
# tt0133093                The Matrix (1999)  1999
# tt1375666                 Inception (2010)  2010
# ...                                    ...   ...
# tt0807721                   Meduzot (2007)  2007
# tt0339642            Daltry Calhoun (2005)  2005
# tt0060880    The Quiller Memorandum (1966)  1966
# tt0152836                      Taal (1999)  1999
# tt0279977            The Navigators (2001)  2001
#
# [10000 rows x 2 columns]

# %%
data["rating"].mean()
# Out:
# 6.38607

# %%
data["rating"].max()
# Out:
# 9.2

# %%
data["rating"].min()
# Out:
# 1.5

# %%
data["genres"].unique()
# Out:
# array(['Crime|Drama', 'Crime|Thriller', 'Drama|Mystery|Thriller', ...,
#        'Drama|War|Adventure|Romance', 'Western|Sci-Fi|Thriller',
#        'Adventure|Comedy|Drama|War'], dtype=object)

# %%
data["rating"].value_counts()
# Out:
# rating
# 7.1    401
# 6.8    401
# 7.2    386
# 6.7    384
# 7.0    382
#       ...
# 1.5      7
# 1.6      6
# 8.9      5
# 9.0      4
# 9.2      2
# Name: count, Length: 77, dtype: int64

# %%
data["rating"].value_counts().sort_index()
# Out:
# rating
# 1.5     7
# 1.6     6
# 1.7    12
# 1.8    12
# 1.9     9
#        ..
# 8.7    13
# 8.8     9
# 8.9     5
# 9.0     4
# 9.2     2
# Name: count, Length: 77, dtype: int64

# %%
data["rating"].value_counts().sort_index(ascending=False)
# Out:
# rating
# 9.2     2
# 9.0     4
# 8.9     5
# 8.8     9
# 8.7    13
#        ..
# 1.9     9
# 1.8    12
# 1.7    12
# 1.6     6
# 1.5     7
# Name: count, Length: 77, dtype: int64

# %% [markdown]
# # Plotting

# %%
# %matplotlib inline

# %%
data.plot()
# Out:
# <Axes: xlabel='id'>

# %%
data.plot(kind = "scatter", x = "rating", y = "votes")
# Out:
# <Axes: xlabel='rating', ylabel='votes'>

# %%
data.plot(kind = 'scatter', x = 'rating', y = 'votes', alpha = 0.3)
# Out:
# <Axes: xlabel='rating', ylabel='votes'>

# %%
data['rating'].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns

# %%
sns.lmplot(x='rating', y='votes', data=data)
# Out:
# C:\Users\yassine\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(data)
# Out:
# C:\Users\yassine\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Ordinary Least Square (OLS) Regression

# %%
import statsmodels.api as sm

# %%
results = sm.OLS(data['votes'], data['rating']).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  votes   R-squared (uncentered):                   0.221
# Model:                            OLS   Adj. R-squared (uncentered):              0.220
# Method:                 Least Squares   F-statistic:                              2829.
# Date:                Fri, 16 Feb 2024   Prob (F-statistic):                        0.00
# Time:                        15:49:51   Log-Likelihood:                     -1.1849e+05
# No. Observations:               10000   AIC:                                  2.370e+05
# Df Residuals:                    9999   BIC:                                  2.370e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# rating      2771.9868     52.115     53.190      0.000    2669.831    2874.143
# ==============================================================================
# Omnibus:                    11448.927   Durbin-Watson:                   0.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1297144.076
# Skew:                           5.966   Prob(JB):                         0.00
# Kurtosis:                      57.505   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
data[data["year"] > 1992]
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
# ...                                    ...   ...     ...     ...        ...
# tt0118635                    Aprile (1998)  1998     6.7    1358   78 mins.
# tt0807721                   Meduzot (2007)  2007     7.0    1357   78 mins.
# tt0339642            Daltry Calhoun (2005)  2005     5.2    1357  100 mins.
# tt0152836                      Taal (1999)  1999     6.5    1356  179 mins.
# tt0279977            The Navigators (2001)  2001     6.9    1356   96 mins.
#
#                                      genres
# id
# tt0111161                       Crime|Drama
# tt0110912                    Crime|Thriller
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller
# ...                                     ...
# tt0118635                            Comedy
# tt0807721                             Drama
# tt0339642        Comedy|Drama|Music|Romance
# tt0152836                   Musical|Romance
# tt0279977                      Comedy|Drama
#
# [6399 rows x 6 columns]

# %%
data[data["year"] == 1955]
# Out:
#                                                        title  year  rating  \
# id
# tt0048545                       Rebel Without a Cause (1955)  1955     7.9
# tt0048424                     The Night of the Hunter (1955)  1955     8.2
# tt0048280                          Lady and the Tramp (1955)  1955     7.4
# tt0048728                            To Catch a Thief (1955)  1955     7.5
# tt0046911                                  Diabolique (1955)  1955     8.3
# tt0048028                                East of Eden (1955)  1955     8.1
# tt0048750                      The Trouble with Harry (1955)  1955     7.2
# tt0048281                             The Ladykillers (1955)  1955     7.9
# tt0048605                         The Seven Year Itch (1955)  1955     7.3
# tt0048021                                      Rififi (1955)  1955     8.2
# tt0048380                              Mister Roberts (1955)  1955     7.8
# tt0047849                       Bad Day at Black Rock (1955)  1955     7.8
# tt0048254                               Killer's Kiss (1955)  1955     6.7
# tt0048356                                       Marty (1955)  1955     7.7
# tt0048261                              Kiss Me Deadly (1955)  1955     7.7
# tt0049096                            The Court Jester (1955)  1955     7.8
# tt0048140                              Guys and Dolls (1955)  1955     7.2
# tt0048473                             Pather Panchali (1955)  1955     8.1
# tt0048641                    Smiles of a Summer Night (1955)  1955     7.8
# tt0048445                                   Oklahoma! (1955)  1955     7.1
# tt0048452                                       Ordet (1955)  1955     8.0
# tt0047811                      All That Heaven Allows (1955)  1955     7.6
# tt0048752                         The Unknown Soldier (1955)  1955     7.8
# tt0047577                           This Island Earth (1955)  1955     5.7
# tt0047885                           Blackboard Jungle (1955)  1955     7.4
# tt0047985                         The Desperate Hours (1955)  1955     7.6
# tt0048491                                      Picnic (1955)  1955     7.3
# tt0048347                 The Man with the Golden Arm (1955)  1955     7.5
# tt0048342                        The Man from Laramie (1955)  1955     7.4
# tt0048801                             We're No Angels (1955)  1955     7.4
# tt0047898                        Bride of the Monster (1955)  1955     3.7
# tt0046889                             The Dam Busters (1955)  1955     7.4
# tt0048673                                  Summertime (1955)  1955     7.6
# tt0048696                                   Tarantula (1955)  1955     6.5
# tt0048393                                 Mr. Arkadin (1955)  1955     7.3
# tt0047795          Abbott and Costello Meet the Mummy (1955)  1955     6.2
# tt0048624                                       Sissi (1955)  1955     6.6
# tt0048729                            To Hell and Back (1955)  1955     7.4
# tt0048579         Samurai II: Duel at Ichijoji Temple (1955)  1955     7.4
# tt0047878                               The Big Combo (1955)  1955     7.5
# tt0048554                     Revenge of the Creature (1955)  1955     5.1
# tt0048316             Love Is a Many-Splendored Thing (1955)  1955     6.6
# tt0048308                              Lola Mont\xe8s (1955)  1955     7.4
# tt0048215                It Came from Beneath the Sea (1955)  1955     5.8
# tt0047876                                   Il Bidone (1955)  1955     7.6
# tt0049674                                 Richard III (1955)  1955     7.6
# tt0048317                         Love Me or Leave Me (1955)  1955     7.2
# tt0049646                    The Quatermass Xperiment (1955)  1955     6.8
# tt0048037  The Criminal Life of Archibaldo de la Cruz (1955)  1955     8.0
# tt0048563                             The Rose Tattoo (1955)  1955     7.1
# tt0048667                       Strategic Air Command (1955)  1955     6.2
# tt0048283                        Land of the Pharaohs (1955)  1955     6.6
# tt0048198                              I Live in Fear (1955)  1955     7.3
#
#            votes     length                                    genres
# id
# tt0048545  30491  111 mins.                             Drama|Romance
# tt0048424  29855   93 mins.                  Drama|Film-Noir|Thriller
# tt0048280  21040   76 mins.            Animation|Family|Music|Romance
# tt0048728  19702  106 mins.            Crime|Mystery|Romance|Thriller
# tt0046911  17731  114 mins.                    Crime|Mystery|Thriller
# tt0048028  14230  115 mins.                                     Drama
# tt0048750  12632   99 mins.                   Comedy|Mystery|Thriller
# tt0048281  11685   91 mins.                     Comedy|Crime|Thriller
# tt0048605  11117  105 mins.                            Comedy|Romance
# tt0048021   9692  122 mins.            Crime|Drama|Film-Noir|Thriller
# tt0048380   7951  123 mins.                          Comedy|Drama|War
# tt0047849   7888   81 mins.            Drama|Mystery|Thriller|Western
# tt0048254   7388   67 mins.            Crime|Drama|Film-Noir|Thriller
# tt0048356   7120   90 mins.                             Drama|Romance
# tt0048261   6849  106 mins.    Crime|Drama|Film-Noir|Mystery|Thriller
# tt0049096   5836  101 mins.           Adventure|Comedy|Family|Musical
# tt0048140   5842  150 mins.                    Comedy|Musical|Romance
# tt0048473   5645  119 mins.                                     Drama
# tt0048641   4816  108 mins.                            Comedy|Romance
# tt0048445   4846  145 mins.                   Musical|Romance|Western
# tt0048452   4758  126 mins.                                     Drama
# tt0047811   4041   89 mins.                             Drama|Romance
# tt0048752   3898  181 mins.                                 Drama|War
# tt0047577   3887   87 mins.                                    Sci-Fi
# tt0047885   3822  101 mins.                                     Drama
# tt0047985   3791  112 mins.                  Film-Noir|Drama|Thriller
# tt0048491   3605  115 mins.                             Drama|Romance
# tt0048347   3477  119 mins.                                     Drama
# tt0048342   3434  104 mins.                                   Western
# tt0048801   3426  106 mins.                      Comedy|Crime|Romance
# tt0047898   3339   69 mins.                             Horror|Sci-Fi
# tt0046889   3200  124 mins.                         Drama|History|War
# tt0048673   3114   99 mins.                             Romance|Drama
# tt0048696   3063   80 mins.                             Horror|Sci-Fi
# tt0048393   2936   93 mins.              Thriller|Crime|Mystery|Drama
# tt0047795   2362   79 mins.                   Comedy|Adventure|Horror
# tt0048624   2352  102 mins.              Comedy|Drama|History|Romance
# tt0048729   2308  106 mins.                Action|Biography|Drama|War
# tt0048579   2208  104 mins.  Action|Adventure|Biography|Drama|History
# tt0047878   1997   84 mins.            Crime|Drama|Film-Noir|Thriller
# tt0048554   1886   82 mins.                             Horror|Sci-Fi
# tt0048316   1872  102 mins.               Biography|Drama|Romance|War
# tt0048308   1781  116 mins.                   Biography|Drama|Romance
# tt0048215   1710   79 mins.                     Fantasy|Horror|Sci-Fi
# tt0047876   1701   00 mins.                                     Drama
# tt0049674   1623  161 mins.                         Drama|History|War
# tt0048317   1603  122 mins.                     Biography|Drama|Music
# tt0049646   1612   82 mins.                             Horror|Sci-Fi
# tt0048037   1604   89 mins.                        Comedy|Crime|Drama
# tt0048563   1488  117 mins.                             Drama|Romance
# tt0048667   1414  112 mins.                              Action|Drama
# tt0048283   1391  106 mins.                             Drama|History
# tt0048198   1360  103 mins.                                     Drama

# %%
data[(data["year"] > 1926) & (data["year"] < 2014)]
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
# ...                                    ...   ...     ...     ...        ...
# tt0807721                   Meduzot (2007)  2007     7.0    1357   78 mins.
# tt0339642            Daltry Calhoun (2005)  2005     5.2    1357  100 mins.
# tt0060880    The Quiller Memorandum (1966)  1966     6.5    1356  104 mins.
# tt0152836                      Taal (1999)  1999     6.5    1356  179 mins.
# tt0279977            The Navigators (2001)  2001     6.9    1356   96 mins.
#
#                                      genres
# id
# tt0111161                       Crime|Drama
# tt0110912                    Crime|Thriller
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller
# ...                                     ...
# tt0807721                             Drama
# tt0339642        Comedy|Drama|Music|Romance
# tt0060880            Drama|Mystery|Thriller
# tt0152836                   Musical|Romance
# tt0279977                      Comedy|Drama
#
# [10000 rows x 6 columns]

# %%
data[(data["year"] > 1926) & (data["year"] < 2014)].sort_values(by="rating", ascending = False).head(10)
# Out:
#                                             title  year  rating   votes  \
# id
# tt0111161         The Shawshank Redemption (1994)  1994     9.2  619479
# tt0068646                    The Godfather (1972)  1972     9.2  474189
# tt0060196   The Good, the Bad and the Ugly (1966)  1966     9.0  195238
# tt0110912                     Pulp Fiction (1994)  1994     9.0  490065
# tt0252487                 Outrageous Class (1975)  1975     9.0    9823
# tt0071562           The Godfather: Part II (1974)  1974     9.0  291169
# tt0108052                 Schindler's List (1993)  1993     8.9  325888
# tt0073486  One Flew Over the Cuckoo's Nest (1975)  1975     8.9  255503
# tt0468569                  The Dark Knight (2008)  2008     8.9  555122
# tt0050083                     12 Angry Men (1957)  1957     8.9  148155
#
#               length                       genres
# id
# tt0111161  142 mins.                  Crime|Drama
# tt0068646  175 mins.                  Crime|Drama
# tt0060196  161 mins.                      Western
# tt0110912  154 mins.               Crime|Thriller
# tt0252487   87 mins.                 Comedy|Drama
# tt0071562  200 mins.                  Crime|Drama
# tt0108052  195 mins.  Biography|Drama|History|War
# tt0073486  133 mins.                        Drama
# tt0468569  152 mins.  Action|Crime|Drama|Thriller
# tt0050083   96 mins.                Drama|Mystery

# %% [markdown]
# # Grouping

# %%
data.groupby(data["year"])["rating"].mean()
# Out:
# year
# 1950    7.545161
# 1951    7.478125
# 1952    7.475676
# 1953    7.106383
# 1954    7.371795
#           ...
# 2007    6.303831
# 2008    6.275260
# 2009    6.287290
# 2010    6.340635
# 2011    6.357143
# Name: rating, Length: 62, dtype: float64

# %%
data.groupby(data["year"])["rating"].max()
# Out:
# year
# 1950    8.7
# 1951    8.3
# 1952    8.4
# 1953    8.3
# 1954    8.8
#        ...
# 2007    8.3
# 2008    8.9
# 2009    8.4
# 2010    8.9
# 2011    8.6
# Name: rating, Length: 62, dtype: float64

# %%
data.groupby(data["year"])["rating"].min()
# Out:
# year
# 1950    6.3
# 1951    6.2
# 1952    6.3
# 1953    2.9
# 1954    6.1
#        ...
# 2007    1.6
# 2008    1.7
# 2009    1.5
# 2010    2.2
# 2011    2.1
# Name: rating, Length: 62, dtype: float64

# %% [markdown]
# # challenges

# %%
data[data["year"]==1996].sort_values(by="rating", ascending=False).head(1)
# Out:
#                   title  year  rating   votes    length                genres
# id
# tt0116282  Fargo (1996)  1996     8.3  187498  98 mins.  Crime|Drama|Thriller

# %%
data[data["rating"] == data["rating"].max()]
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0068646             The Godfather (1972)  1972     9.2  474189  175 mins.
#
#                 genres
# id
# tt0111161  Crime|Drama
# tt0068646  Crime|Drama

# %%
data.sort_values(by="votes", ascending=False).head(5)
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0468569           The Dark Knight (2008)  2008     8.9  555122  152 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0068646             The Godfather (1972)  1972     9.2  474189  175 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
#
#                                 genres
# id
# tt0111161                  Crime|Drama
# tt0468569  Action|Crime|Drama|Thriller
# tt0110912               Crime|Thriller
# tt0068646                  Crime|Drama
# tt0137523       Drama|Mystery|Thriller

# %%
data[(data['year'] >= 1960) & (data['year'] <= 1970)].groupby(data['year'])['rating'].mean()
# Out:
# year
# 1960    7.247917
# 1961    7.195349
# 1962    7.349057
# 1963    7.103922
# 1964    6.865217
# 1965    6.996875
# 1966    6.895652
# 1967    7.169091
# 1968    6.967213
# 1969    7.011321
# 1970    6.987692
# Name: rating, dtype: float64

# %% [markdown]
# # cleaning Data

# %%
data['formatted data'] = data['title'].str.split('\(').str[0]

# %%
data.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres             formatted data
# id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception

# %%
data['formatted length']=data['length'].str.split().str.get(0)

# %%
data.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres             formatted data  \
# id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception
#
#           formatted length
# id
# tt0111161              142
# tt0110912              154
# tt0137523              139
# tt0133093              136
# tt1375666              148
